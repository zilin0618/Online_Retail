# %% [markdown]
# # Online Retail Project

# %% [markdown]
# # Preparation

# %%
# Install and import required libraries
# pyfpgrowth(https://fp-growth.readthedocs.io/en/latest/)
# !pip install pyfpgrowth # ! is needed for Google Colab, it is optional for GCP
import os
import pyfpgrowth
import pandas as pd
# Out:
# Collecting pyfpgrowth
#   Downloading pyfpgrowth-1.0.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 4.1 MB/s
# Building wheels for collected packages: pyfpgrowth
#   Building wheel for pyfpgrowth (setup.py) ... done
#   Created wheel for pyfpgrowth: filename=pyfpgrowth-1.0-py2.py3-none-any.whl size=5504 sha256=3d4f2c91372acf1bd7b59c65c6a5a089709e90ca2803c7e9f5a87f8480d712ef
#   Stored in directory: /root/.cache/pip/wheels/73/97/4b/f12ac994f6bbb99597396255435824c73ad3916be1e678be55
# Successfully built pyfpgrowth
# Installing collected packages: pyfpgrowth
# Successfully installed pyfpgrowth-1.0

# %% [markdown]
# # Dataset Description
# [Online Retail](http://archive.ics.uci.edu/ml/datasets/online+retail#) contains all the transactions occurring between 01-12-2010 and 09-12-2011 for a UK-based and registered non-store online retail. The purpose of this project is to extract Association Rules by using Frequent Patterm Mining algorithm (FPGrowth Tree).
#
# ## Dictionary
# - InvoiceNo: Invoice number. Nominal, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.
# - StockCode: Product (item) code. Nominal, a 5-digit integral number uniquely assigned to each distinct product.
# - Description: Product (item) name. Nominal.
# - Quantity: The quantities of each product (item) per transaction. Numeric.
# - InvoiceDate: Invice Date and time. Numeric, the day and time when each transaction was generated.
# - UnitPrice: Unit price. Numeric, Product price per unit in sterling.
# - CustomerID: Customer number. Nominal, a 5-digit integral number uniquely assigned to each customer.
# - Country: Country name. Nominal, the name of the country where each customer resides.

# %% [markdown]
# ## 1
# Download the Online Retail data from given link and read it as Pandas DataFrame. Display the first few rows of the data. Examine its properties such as rows, columns, any missing values and columns names. Read the data dictionary and confirm your understanding of each column.

# %%
# Following shell commands will download the data and list contents of directory. 
# !wget -q -N 'http://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx'
# !ls 
# For convenience the file name is changed.
# !mv 'Online Retail.xlsx' OnlineRetail.xlsx
# Out:
# 'Online Retail.xlsx'   sample_data

# %%
# read_excel function reads excel sheet as a DataFrame
dataset = pd.read_excel('OnlineRetail.xlsx')

# %%
dataset.head(5)
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
# check shape (rows, columns) of dataset
print(dataset.shape)
# check null (missing) values in individual columns
print(dataset.isnull().sum())
# check null (missing) values in the dataset
print(dataset.isnull().sum().sum()) # 136534
# The columns names
print(dataset.columns)
# Out:
# (541909, 8)
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64
# 136534
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %% [markdown]
# ## 2
# InvoiceNumber column provides a unique id to each transaction. Some invoice number start with 'c' indicating cancelled transactions. Filter cancelled transactions from your dataset. Then, generate frequency count of items in each transaction. Create a list of unique Invoices that have more than 5 and less than 10 items. Final data must not include cancelled transactions and transactions with less than 5 or more than 10 items.

# %%
# If InvoiceNo starts with letter 'c', it indicates a cancellation.
dataset_x = dataset[~ dataset['InvoiceNo'].str.startswith('C', na=False)] # filter 9288 cancelled or NaN transations
# Count cancelled invoices
dataset_x['InvoiceNo'].count() # 532621 left out of 541909
# Out:
# 532621

# %%
# filter transaction where items baught are less than 5
min_items_in_transaction = 5
max_items_in_transaction = 10
InvoiceNo_Count = dataset_x['InvoiceNo'].value_counts() # 25900 transaction
InvoiceNo_List = list(set(InvoiceNo_Count[InvoiceNo_Count.between(min_items_in_transaction, max_items_in_transaction)].index.tolist()))
dataset_x2 = dataset_x[dataset_x['InvoiceNo'].isin(InvoiceNo_List)]
print('transactions in final dataset', dataset_x2.shape[0])
print('Invoices', len(InvoiceNo_List))
# Out:
# transactions in final dataset 26975
# Invoices 3646

# %% [markdown]
# ## 3
# Transform your filtered dataset into two python dictionaries. Each item of the first dictionary StockCode2Alias_Dict will have StockCode as key and a unique-id as value. Each item of the second dictionary Alias2StockCode_Dict will have unique-id as key and StockCode and Description as value. A StockCode can have more than one descriptions. Keep the first description of each StockCode.

# %%
# print(dataset_x2[dataset_x2['StockCode'] == '85123A']['Description'].unique())
StockCode2Alias_Dict = {}
Alias2StockCode_Dict = {}
StockCodes = list(dataset_x2['StockCode'].unique())
for c in StockCodes:
  if c not in StockCode2Alias_Dict.keys():
    # add item to StockCode2Alias_Dict
    StockCode2Alias_Dict[c] = len(StockCode2Alias_Dict) # StockCode_Num_Alias
    # keep the first descriotion
    desc = dataset_x2[dataset_x2['StockCode'] == c]['Description'].unique()[0]
    # add item to Alias2StockCode_Dict
    Alias2StockCode_Dict[StockCode2Alias_Dict[c]] = (c, desc) # StockCode_Num_Alias
# print(StockCode2Alias_Dict)
print(Alias2StockCode_Dict)
# Out:
# {0: ('85123A', 'WHITE HANGING HEART T-LIGHT HOLDER'), 1: (71053, 'WHITE METAL LANTERN'), 2: ('84406B', 'CREAM CUPID HEARTS COAT HANGER'), 3: ('84029G', 'KNITTED UNION FLAG HOT WATER BOTTLE'), 4: ('84029E', 'RED WOOLLY HOTTIE WHITE HEART.'), 5: (22752, 'SET 7 BABUSHKA NESTING BOXES'), 6: (21730, 'GLASS STAR FROSTED T-LIGHT HOLDER'), 7: (22783, 'SET 3 WICKER OVAL BASKETS W LIDS'), 8: (22961, 'JAM MAKING SET PRINTED'), 9: (22960, 'JAM MAKING SET WITH JARS'), 10: (22663, 'JUMBO BAG DOLLY GIRL DESIGN'), 11: ('85049A', 'TRADITIONAL CHRISTMAS RIBBONS'), 12: (22168, 'ORGANISER WOOD ANTIQUE WHITE '), 13: (22662, 'LUNCH BAG DOLLY GIRL DESIGN'), 14: (79321, 'CHILLI LIGHTS'), 15: (22780, 'LIGHT GARLAND BUTTERFILES PINK'), 16: (22779, 'WOODEN OWLS LIGHT GARLAND '), 17: (22466, 'FAIRY TALE COTTAGE NIGHTLIGHT'), 18: (21731, 'RED TOADSTOOL LED NIGHT LIGHT'), 19: (22150, '3 STRIPEY MICE FELTCRAFT'), 20: (22619, 'SET OF 6 SOLDIER SKITTLES'), 21: (21891, 'TRADITIONAL WOODEN SKIPPING ROPE'), 22: (21889, 'WOODEN BOX OF DOMINOES'), 23: (22827, 'RUSTIC  SEVENTEEN DRAWER SIDEBOARD'), 24: (22127, 'PARTY CONES CARNIVAL ASSORTED'), 25: (22128, 'PARTY CONES CANDY ASSORTED'), 26: (22502, 'PICNIC BASKET WICKER SMALL'), 27: (84879, 'ASSORTED COLOUR BIRD ORNAMENT'), 28: (22338, 'STAR DECORATION PAINTED ZINC '), 29: (21494, 'ROTATING LEAVES T-LIGHT HOLDER'), 30: (21915, 'RED  HARMONICA IN BOX '), 31: (22938, 'CUPCAKE LACE PAPER SET 6'), 32: (22768, 'FAMILY PHOTO FRAME CORNICE'), 33: (22767, 'TRIPLE PHOTO FRAME CORNICE '), 34: ('82494L', 'WOODEN FRAME ANTIQUE WHITE '), 35: (21481, 'FAWN BLUE HOT WATER BOTTLE'), 36: (22632, 'HAND WARMER RED RETROSPOT'), 37: (22837, 'HOT WATER BOTTLE BABUSHKA '), 38: (21479, 'WHITE SKULL HOT WATER BOTTLE '), 39: (21485, 'RETROSPOT HEART HOT WATER BOTTLE'), 40: (22111, 'SCOTTIE DOG HOT WATER BOTTLE'), 41: (22113, 'GREY HEART HOT WATER BOTTLE'), 42: (21154, 'RED RETROSPOT OVEN GLOVE '), 43: (22189, 'CREAM HEART CARD HOLDER'), 44: (17021, 'NAMASTE SWAGAT INCENSE'), 45: (22059, 'CERAMIC STRAWBERRY DESIGN MUG'), 46: (22188, 'BLACK HEART CARD HOLDER'), 47: (84678, 'CLASSICAL ROSE SMALL VASE'), 48: (22784, 'LANTERN CREAM GAZEBO '), 49: (21441, 'BLUE BIRDHOUSE DECORATION'), 50: (22423, 'REGENCY CAKESTAND 3 TIER'), 51: (22865, 'HAND WARMER OWL DESIGN'), 52: (22485, 'SET OF 2 WOODEN MARKET CRATES'), 53: (22807, 'SET OF 6 T-LIGHTS TOADSTOOLS'), 54: (22633, 'HAND WARMER UNION JACK'), 55: (22866, 'HAND WARMER SCOTTY DOG DESIGN'), 56: (21135, 'VICTORIAN  METAL POSTCARD SPRING'), 57: (22173, 'METAL 4 HOOK HANGER FRENCH CHATEAU'), 58: (22626, 'BLACK KITCHEN SCALES'), 59: (22625, 'RED KITCHEN SCALES'), 60: (22624, 'IVORY KITCHEN SCALES'), 61: (21929, 'JUMBO BAG PINK VINTAGE PAISLEY'), 62: ('85099B', 'JUMBO BAG RED RETROSPOT'), 63: (22411, 'JUMBO SHOPPER VINTAGE RED PAISLEY'), 64: (22222, 'CAKE PLATE LOVEBIRD WHITE'), 65: (22947, 'WOODEN ADVENT CALENDAR RED'), 66: (21743, 'STAR PORTABLE TABLE LIGHT '), 67: (22187, 'GREEN CHRISTMAS TREE CARD HOLDER'), 68: (22164, 'STRING OF STARS CARD HOLDER'), 69: (72598, 'SET/12 TAPER CANDLES'), 70: (21258, 'VICTORIAN SEWING BOX LARGE'), 71: (22627, 'MINT KITCHEN SCALES'), 72: (22487, 'WHITE WOOD GARDEN PLANT LADDER'), 73: (20754, 'RETROSPOT RED WASHING UP GLOVES'), 74: (22740, 'POLKADOT PEN'), 75: (22825, 'DECORATIVE PLANT POT WITH FRIEZE'), 76: (22680, 'FRENCH BLUE METAL DOOR SIGN 5'), 77: (22797, 'CHEST OF DRAWERS GINGHAM HEART '), 78: (21843, 'RED RETROSPOT CAKE STAND'), 79: (22834, 'HAND WARMER BABUSHKA DESIGN'), 80: (22867, 'HAND WARMER BIRD DESIGN'), 81: (22112, 'CHOCOLATE HOT WATER BOTTLE'), 82: (22599, 'CHRISTMAS MUSICAL ZINC STAR'), 83: (22597, 'CHRISTMAS MUSICAL ZINC HEART '), 84: (22336, 'DOVE DECORATION PAINTED ZINC '), 85: (21922, 'UNION STRIPE WITH FRINGE  HAMMOCK'), 86: (35961, 'FOLKART ZINC HEART CHRISTMAS DEC'), 87: (20749, 'ASSORTED COLOUR MINI CASES'), 88: (22694, 'WICKER STAR '), 89: ('84884A', 'ANT WHITE WIRE HEART SPIRAL'), 90: ('51014C', 'FEATHER PEN,COAL BLACK'), 91: ('51014L', 'FEATHER  ...

# %% [markdown]
# ## 4
# Create a list and name it as transactions. Append the items from InvoiceNo_List, created in step 2, to it. Each item in transactions contains list of StockCodes of the items bought.

# %%
transactions = []
for invoice_no in InvoiceNo_List:
    items = dataset_x2[dataset_x2['InvoiceNo'] == invoice_no]['StockCode'].to_list()   
    transactions.append([StockCode2Alias_Dict[i] for i in items])    
print('transactions_db size', len(transactions))
print(transactions[0:9])
# Out:
# transactions_db size 3646
# [[2074, 2073, 1282, 380, 286, 215, 452, 1829], [2562, 2521, 18, 35, 38, 124, 1861], [512, 1114, 1570, 1568, 1842], [1323, 1001, 1136, 1629, 1630, 1631, 1631], [1577, 198, 197, 768, 20, 21, 799], [1836, 1990, 1981, 1992, 1989, 577, 2019, 1391], [1007, 736, 992, 1008, 1009, 1010, 729, 962], [146, 1235, 1314, 126, 137, 583, 9, 1959], [215, 158, 195, 822, 419, 46, 317]]

# %% [markdown]
# ## 5
# Extract Association Rules by using Frequent Patterm Mining algorithm (FPGrowth Tree). The trasactions list is going to be the input to the algorithm. Print the extracted rules with the help of Alias2StockCode_Dict created in step 3.

# %%
patterns = pyfpgrowth.find_frequent_patterns(transactions, 5) # try different support threshold values

# %%
rules = pyfpgrowth.generate_association_rules(patterns, 1) # try different probability threshold values
# rules are a dictionary of antecedents and consequents.

# %%
for antecedents, consequents in rules.items():
    antec_list =[]
    conseq_list =[]
    for a in antecedents:
        antec_list.append(Alias2StockCode_Dict[a][1])
    for c in consequents[0]:
        conseq_list.append(Alias2StockCode_Dict[c][1])
    print(antec_list, '-->', conseq_list, consequents[1])
# Out:
# ['SMALL CHOCOLATES PINK BOWL'] --> ['SMALL DOLLY MIX DESIGN ORANGE BOWL'] 1.0
# ['HANGING HEART BONHEUR'] --> ['HOME SWEET HOME HANGING HEART'] 1.0
# ['HERB MARKER ROSEMARY', 'HERB MARKER PARSLEY'] --> ['HERB MARKER BASIL'] 1.0
# ['HERB MARKER BASIL', 'HERB MARKER PARSLEY'] --> ['HERB MARKER THYME'] 1.0
# ['HERB MARKER THYME', 'HERB MARKER PARSLEY'] --> ['HERB MARKER BASIL'] 1.0
# ["POPPY'S PLAYHOUSE BATHROOM"] --> ["POPPY'S PLAYHOUSE BEDROOM ", "POPPY'S PLAYHOUSE KITCHEN"] 1.0
# ["POPPY'S PLAYHOUSE LIVINGROOM ", "POPPY'S PLAYHOUSE BATHROOM"] --> ["POPPY'S PLAYHOUSE BEDROOM ", "POPPY'S PLAYHOUSE KITCHEN"] 1.0
# ["POPPY'S PLAYHOUSE BEDROOM ", "POPPY'S PLAYHOUSE BATHROOM"] --> ["POPPY'S PLAYHOUSE KITCHEN"] 1.0
# ["POPPY'S PLAYHOUSE KITCHEN", "POPPY'S PLAYHOUSE BATHROOM"] --> ["POPPY'S PLAYHOUSE BEDROOM "] 1.0
# ["POPPY'S PLAYHOUSE BEDROOM ", "POPPY'S PLAYHOUSE LIVINGROOM ", "POPPY'S PLAYHOUSE BATHROOM"] --> ["POPPY'S PLAYHOUSE KITCHEN"] 1.0
# ["POPPY'S PLAYHOUSE LIVINGROOM ", "POPPY'S PLAYHOUSE KITCHEN", "POPPY'S PLAYHOUSE BATHROOM"] --> ["POPPY'S PLAYHOUSE BEDROOM "] 1.0
# ['GEMSTONE CHANDELIER T-LIGHT HOLDER'] --> ['IVORY CHANDELIER T-LIGHT HOLDER'] 1.0
# ['IVORY CHANDELIER T-LIGHT HOLDER'] --> ['GEMSTONE CHANDELIER T-LIGHT HOLDER'] 1.0
# ['GEMSTONE CHANDELIER T-LIGHT HOLDER', 'FLOWERS CHANDELIER T-LIGHT HOLDER'] --> ['IVORY CHANDELIER T-LIGHT HOLDER'] 1.0
# ['IVORY CHANDELIER T-LIGHT HOLDER', 'FLOWERS CHANDELIER T-LIGHT HOLDER'] --> ['GEMSTONE CHANDELIER T-LIGHT HOLDER'] 1.0
# ['SMALL ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['CREAM HEART CARD HOLDER', 'SMALL ZINC HEART WALL ORGANISER'] --> ['BLACK HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['BLACK HEART CARD HOLDER', 'SMALL ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['WOOD BLACK BOARD ANT WHITE FINISH', 'SMALL ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER'] 1.0
# ['BLACK HEART CARD HOLDER', 'LARGE ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['LARGE ZINC HEART WALL ORGANISER', 'SMALL ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['BLACK HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE'] --> ['CREAM HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['3 HOOK PHOTO SHELF ANTIQUE WHITE', 'SMALL ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['CREAM HEART CARD HOLDER', 'LARGE ZINC HEART WALL ORGANISER'] --> ['BLACK HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['CREAM HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE'] --> ['WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['3 HOOK PHOTO SHELF ANTIQUE WHITE', 'LARGE ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER', 'SMALL ZINC HEART WALL ORGANISER'] --> ['WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['CREAM HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH', 'SMALL ZINC HEART WALL ORGANISER'] --> ['BLACK HEART CARD HOLDER'] 1.0
# ['BLACK HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH', 'SMALL ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER'] 1.0
# ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER', 'LARGE ZINC HEART WALL ORGANISER'] --> ['3 HOOK PHOTO SHELF ANTIQUE WHITE', 'WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['CREAM HEART CARD HOLDER', 'LARGE ZINC HEART WALL ORGANISER', 'SMALL ZINC HEART WALL ORGANISER'] --> ['BLACK HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['BLACK HEART CARD HOLDER', 'LARGE ZINC HEART WALL ORGANISER', 'SMALL ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE'] --> ['WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['CREAM HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'SMALL ZINC HEART WALL ORGANISER'] --> ['BLACK HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['BLACK HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'SMALL ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['BLACK HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH', 'LARGE ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE'] 1.0
# ['WOOD BLACK BOARD ANT WHITE FINISH', 'LARGE ZINC HEART WALL ORGANISER', 'SMALL ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE'] 1.0
# ['BLACK HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'WOOD BLACK BOARD ANT WHITE FINISH'] --> ['CREAM HEART CARD HOLDER'] 1.0
# ['3 HOOK PHOTO SHELF ANTIQUE WHITE', 'WOOD BLACK BOARD ANT WHITE FINISH', 'SMALL ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER'] 1.0
# ['BLACK HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'LARGE ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['3 HOOK PHOTO SHELF ANTIQUE WHITE', 'LARGE ZINC HEART WALL ORGANISER', 'SMALL ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['CREAM HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH', 'LARGE ZINC HEART WALL ORGANISER'] --> ['BLACK HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE'] 1.0
# ['CREAM HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'WOOD BLACK BOARD ANT WHITE FINISH'] --> ['BLACK HEART CARD HOLDER'] 1.0
# ['CREAM HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'LARGE ZINC HEART WALL ORGANISER'] --> ['BLACK HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['3 HOOK PHOTO SHELF ANTIQUE WHITE', 'WOOD BLACK BOARD ANT WHITE FINISH', 'LARGE ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER'] 1.0
# ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH', 'LARGE ZINC HEART WALL ORGANISER'] --> ['3 HOOK PHOTO SHELF ANTIQUE WHITE'] 1.0
# ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER', 'LARGE ZINC HEART WALL ORGANISER', 'SMALL ZINC HEART WALL ORGANISER'] --> ['3 HOOK PHOTO SHELF ANTIQUE WHITE', 'WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['CREAM HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH', 'LARGE ZINC HEART WALL ORGANISER', 'SMALL ZINC HEART WALL ORGANISER'] --> ['BLACK HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE'] 1.0
# ['BLACK HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH', 'LARGE ZINC HEART WALL ORGANISER', 'SMALL ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE'] 1.0
# ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'WOOD BLACK BOARD ANT WHITE FINISH'] --> ['SMALL ZINC HEART WALL ORGANISER'] 1.0
# ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'SMALL ZINC HEART WALL ORGANISER'] --> ['WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['CREAM HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'WOOD BLACK BOARD ANT WHITE FINISH', 'SMALL ZINC HEART WALL ORGANISER'] --> ['BLACK HEART CARD HOLDER'] 1.0
# ['BLACK HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'WOOD BLACK BOARD ANT WHITE FINISH', 'SMALL ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER'] 1.0
# ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'LARGE ZINC HEART WALL ORGANISER'] --> ['WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['CREAM HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'LARGE ZINC HEART WALL ORGANISER', 'SMALL ZINC HEART WALL ORGANISER'] --> ['BLACK HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['BLACK HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'LARGE ZINC HEART WALL ORGANISER', 'SMALL ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['BLACK HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'WOOD BLACK BOARD ANT WHITE FINISH', 'LARGE ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER'] 1.0
# ['3 HOOK PHOTO SHELF ANTIQUE WHITE', 'WOOD BLACK BOARD ANT WHITE FINISH', 'LARGE ZINC HEART WALL ORGANISER', 'SMALL ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER'] 1.0
# ['CREAM HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'WOOD BLACK BOARD ANT WHITE FINISH', 'LARGE ZINC HEART WALL ORGANISER'] --> ['BLACK HEART CARD HOLDER'] 1.0
# ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'WOOD BLACK BOARD ANT WHITE FINISH', 'LARGE ZINC HEART WALL ORGANISER'] --> ['SMALL ZINC HEART WALL ORGANISER'] 1.0
# ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'LARGE ZINC HEART WALL ORGANISER', 'SMALL ZINC HEART WALL ORGANISER'] --> ['WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH', 'LARGE ZINC HEART WALL ORGANISER', 'SMALL ZINC HEART WALL ORGANISER'] --> ['3 HOOK PHOTO SHELF ANTIQUE WHITE'] 1.0
# ['CREAM HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'WOOD BLACK BOARD ANT WHITE FINISH', 'LARGE ZINC HEART WALL ORGANISER', 'SMALL ZINC HEART WALL ORGANISER'] --> ['BLACK HEART CARD HOLDER'] 1.0
# ['BLACK HEART CARD HOLDER', '3 HOOK PHOTO SHELF ANTIQUE WHITE', 'WOOD BLACK BOARD ANT WHITE FINISH', 'LARGE ZINC HEART WALL ORGANISER', 'SMALL ZINC HEART WALL ORGANISER'] --> ['CREAM HEART CARD HOLDER'] 1.0
# ['GREEN VINTAGE SPOT BEAKER', 'BLUE VINTAGE SPOT BEAKER'] --> ['RED VINTAGE SPOT BEAKER'] 1.0
# ['FEATHER PEN,LIGHT PINK', 'FEATHER PEN,HOT PINK'] --> ['FEATHER PEN,COAL BLACK'] 1.0
# ['CLASSIC CHROME BICYCLE BELL ', 'CLASSIC BICYCLE CLIPS '] --> ['BICYCLE PUNCTURE REPAIR KIT '] 1.0
# ['ALARM CLOCK BAKELIKE GREEN', 'CAMOUFLAGE DESIGN TEDDY'] --> ['BAG 250g SWIRLY MARBLES'] 1.0
# ['VINTAGE SNAP CARDS', 'CAMOUFLAGE DESIGN TEDDY'] --> ['BAG 250g SWIRLY MARBLES'] 1.0
# ['TOILET METAL SIGN', 'KITCHEN METAL SIGN'] --> ['BATHROOM METAL SIGN'] 1.0
# ['SET/6 COLLAGE PAPER PLATES'] --> ['SET/6 COLLAGE PAPER CUPS'] 1.0
# ['PINK VINTAGE SPOT BEAKER', 'BLUE VINTAGE SPOT BEAKER'] --> ['RED VINTAGE SPOT BEAKER'] 1.0
# ['PINK 3 PIECE POLKADOT CUTLERY SET', 'GREEN 3 PIECE POLKADOT CUTLERY SET'] --> ['BLUE 3 PIECE POLKADOT CUTLERY SET'] 1.0
# ['DOG LICENCE WALL ART', 'STOP FOR TEA WALL ART'] --> ['BICYCLE SAFTEY WALL ART'] 1.0
# ['FELTCRAFT DOLL ROSIE', 'FELTCRAFT DOLL EMILY'] --> ['FELTCRAFT PRINCESS CHARLOTTE DOLL'] 1.0
# ['FELTCRAFT DOLL MOLLY', 'FELTCRAFT PRINCESS CHARLOTTE DOLL'] --> ['FELTCRAFT DOLL ROSIE', 'FELTCRAFT DOLL EMILY'] 1.0
# ['FELTCRAFT DOLL MOLLY', 'FELTCRAFT DOLL EMILY'] --> ['FELTCRAFT DOLL ROSIE', 'FELTCRAFT PRINCESS CHARLOTTE DOLL'] 1.1428571428571428
# ['FELTCRAFT DOLL ROSIE', 'FELTCRAFT DOLL MOLLY', 'FELTCRAFT PRINCESS CHARLOTTE DOLL'] --> ['FELTCRAFT PRINCESS LOLA DOLL'] 1.0
# ['FELTCRAFT DOLL ROSIE', 'FELTCRAFT DOLL MOLLY', 'FELTCRAFT DOLL EMILY'] --> ['FELTCRAFT PRINCESS CHARLOTTE DOLL'] 1.3333333333333333
# ['FELTCRAFT DOLL ROSIE', 'FELTCRAFT PRINCESS CHARLOTTE DOLL', 'FELTCRAFT DOLL EMILY'] --> ['FELTCRAFT DOLL MOLLY'] 1.0
# ['FELTCRAFT DOLL MOLLY', 'FELTCRAFT PRINCESS CHARLOTTE DOLL', 'FELTCRAFT DOLL EMILY'] --> ['FELTCRAFT DOLL ROSIE'] 1.6
# ['ASSORTED COLOURS SILK FAN', 'RED PAPER PARASOL'] --> ['PINK PAPER PARASOL '] 1.0
# ['ASSORTED COLOURS SILK FAN', 'PINK PAPER PARASOL '] --> ['RED PAPER PARASOL'] 1.0
# ['LUNCH BOX I LOVE LONDON', 'CARD I LOVE LONDON '] --> ['LONDON BUS COFFEE MUG'] 1.0
# ['RED DRAWER KNOB ACRYLIC EDWARDIAN', 'BLUE SPOT CERAMIC DRAWER KNOB'] --> ['PINK DRAWER KNOB ACRYLIC EDWARDIAN'] 1.4
# ['RED STRIPE CERAMIC DRAWER KNOB', 'RED DRAWER KNOB ACRYLIC EDWARDIAN'] --> ['PINK DRAWER KNOB ACRYLIC EDWARDIAN'] 1.0
# ['RED DRAWER KNOB ACRYLIC EDWARDIAN', 'PURPLE DRAWERKNOB ACRYLIC EDWARDIAN'] --> ['PINK DRAWER KNOB ACRYLIC EDWARDIAN'] 1.1111111111111112
# ['CLEAR DRAWER KNOB ACRYLIC EDWARDIAN', 'BLUE DRAWER KNOB ACRYLIC EDWARDIAN'] --> ['PINK DRAWER KNOB ACRYLIC EDWARDIAN'] 1.0
# ['LARGE CERAMIC TOP STORAGE JAR', 'SMALL CERAMIC TOP STORAGE JAR '] --> ['MEDIUM CERAMIC TOP STORAGE JAR'] 1.0
# ['HOT WATER BOTTLE TEA AND SYMPATHY', 'ENGLISH ROSE HOT WATER BOTTLE'] --> ['CHOCOLATE HOT WATER BOTTLE', 'HOT WATER BOTTLE I AM SO POORLY'] 1.0
# ['CHOCOLATE HOT WATER BOTTLE', 'ENGLISH ROSE HOT WATER BOTTLE'] --> ['HOT WATER BOTTLE I AM SO POORLY', 'HOT WATER BOTTLE TEA AND SYMPATHY'] 1.0
# ['CHOCOLATE HOT WATER BOTTLE', 'HOT WATER BOTTLE I AM SO POORLY', 'ENGLISH ROSE HOT WATER BOTTLE'] --> ['HOT WATER BOTTLE TEA AND SYMPATHY'] 1.0
# ['CHOCOLATE HOT WATER BOTTLE', 'HOT WATER BOTTLE TEA AND SYMPATHY', 'ENGLISH ROSE HOT WATER BOTTLE'] --> ['HOT WATER BOTTLE I AM SO POORLY'] 1.0
# ['HOT WATER BOTTLE I AM SO POORLY', 'HOT WATER BOTTLE TEA AND SYMPATHY', 'ENGLISH ROSE HOT WATER BOTTLE'] --> ['CHOCOLATE HOT WATER BOTTLE'] 1.0
# ['WHITE SPOT BLUE CERAMIC DRAWER KNOB', 'BLUE STRIPE CERAMIC DRAWER KNOB'] --> ['BLUE SPOT CERAMIC DRAWER KNOB'] 1.0
# ['SET OF 6 TEA TIME BAKING CASES', 'SET OF 6 SNACK LOAF BAKING CASES'] --> ['SET OF 12 FAIRY CAKE BAKING CASES'] 1.8
# ['SET OF 6 TEA TIME BAKING CASES', 'SET OF 6 SNACK LOAF BAKING CASES', 'SET 40 HEART SHAPE PETIT FOUR CASES'] --> ['SET OF 12 FAIRY CAKE BAKING CASES'] 1.0
# ['SET OF 6 SNACK LOAF BAKING CASES', 'SET OF 12 MINI LOAF BAKING CASES', 'SET 40 HEART SHAPE PETIT FOUR CASES'] --> ['SET OF 12 FAIRY CAKE BAKING CASES'] 1.0
# ['SET OF 6 TEA TIME BAKING CASES', 'SET OF 6 SNACK LOAF BAKING CASES', 'SET OF 12 MINI LOAF BAKING CASES', 'SET 40 HEART SHAPE PETIT FOUR CASES'] --> ['SET OF 12 FAIRY CAKE BAKING CASES'] 1.0
# ['SET OF 6 TEA TIME BAKING CASES', 'SET OF 12 MINI LOAF BAKING CASES', 'SET 40 HEART SHAPE PETIT FOUR CASES'] --> ['SET OF 12 FAIRY CAKE BAKING CASES'] 1.0
# ['SPACEBOY LUNCH BOX ', 'CHILDS BREAKFAST SET DOLLY GIRL '] --> ['DOLLY GIRL LUNCH BOX'] 1.0
# ['DOLLY GIRL LUNCH BOX', 'CHILDS BREAKFAST SET DOLLY GIRL '] --> ['SPACEBOY LUNCH BOX '] 1.0
# ['RECYCLED ACAPULCO MAT PINK', 'RECYCLED ACAPULCO MAT LAVENDER', 'RECYCLED ACAPULCO MAT BLUE'] --> ['RECYCLED ACAPULCO MAT GREEN'] 1.0
# ['RECYCLED ACAPULCO MAT LAVENDER', 'RECYCLED ACAPULCO MAT TURQUOISE', 'RECYCLED ACAPULCO MAT BLUE'] --> ['RECYCLED ACAPULCO MAT GREEN'] 1.0
# ['RECYCLED ACAPULCO MAT PINK', 'RECYCLED ACAPULCO MAT LAVENDER', 'RECYCLED ACAPULCO MAT TURQUOISE', 'RECYCLED ACAPULCO MAT BLUE'] --> ['RECYCLED ACAPULCO MAT GREEN'] 1.0
# ['RECYCLED ACAPULCO MAT PINK', 'RECYCLED ACAPULCO MAT LAVENDER'] --> ['RECYCLED ACAPULCO MAT GREEN'] 1.0
# ['RECYCLED ACAPULCO MAT PINK', 'RECYCLED ACAPULCO MAT LAVENDER', 'RECYCLED ACAPULCO MAT TURQUOISE'] --> ['RECYCLED ACAPULCO MAT GREEN'] 1.0
# ['BLACK/BLUE POLKADOT UMBRELLA', 'EDWARDIAN PARASOL RED'] --> ['RED RETROSPOT UMBRELLA'] 1.0
# ['TRADITIONAL WOODEN SKIPPING ROPE', 'TRADITIONAL MODELLING CLAY'] --> ['WOODEN SCHOOL COLOURING SET', 'PAINT YOUR OWN CANVAS SET'] 1.0
# ['TRADITIONAL WOODEN SKIPPING ROPE', 'PAINT YOUR OWN CANVAS SET'] --> ['WOODEN SCHOOL COLOURING SET', 'TRADITIONAL MODELLING CLAY'] 1.0
# ['TRADITIONAL WOODEN SKIPPING ROPE', 'WOODEN SCHOOL COLOURING SET', 'PAINT YOUR OWN CANVAS SET'] --> ['TRADITIONAL MODELLING CLAY'] 1.0
# ['TRADITIONAL WOODEN SKIPPING ROPE', 'TRADITIONAL MODELLING CLAY', 'PAINT YOUR OWN CANVAS SET'] --> ['WOODEN SCHOOL COLOURING SET'] 1.0
# ['WORLD WAR 2 GLIDERS ASSTD DESIGNS', 'PAINT YOUR OWN CANVAS SET'] --> ['MINI PAINT SET VINTAGE ', 'WOODEN SCHOOL COLOURING SET', 'TRADITIONAL MODELLING CLAY'] 1.0
# ['MINI PAINT SET VINTAGE ', 'WORLD WAR 2 GLIDERS ASSTD DESIGNS', 'TRADITIONAL MODELLING CLAY'] --> ['WOODEN SCHOOL COLOURING SET'] 1.0
# ['MINI PAINT SET VINTAGE ', 'WORLD WAR 2 GLIDERS ASSTD DESIGNS', 'PAINT YOUR OWN CANVAS SET'] --> ['WOODEN SCHOOL COLOURING SET', 'TRADITIONAL MODELLING CLAY'] 1.0
# ['MINI PAINT SET VINTAGE ', 'TRADITIONAL MODELLING CLAY', 'PAINT YOUR OWN CANVAS SET'] --> ['WOODEN SCHOOL COLOURING SET'] 1.0
# ['WORLD WAR 2 GLIDERS ASSTD DESIGNS', 'TRADITIONAL MODELLING CLAY', 'PAINT YOUR OWN CANVAS SET'] --> ['MINI PAINT SET VINTAGE ', 'WOODEN SCHOOL COLOURING SET'] 1.0
# ['WOODEN SCHOOL COLOURING SET', 'WORLD WAR 2 GLIDERS ASSTD DESIGNS', 'PAINT YOUR OWN CANVAS SET'] --> ['MINI PAINT SET VINTAGE ', 'TRADITIONAL MODELLING CLAY'] 1.0
# ['MINI PAINT SET VINTAGE ', 'WOODEN SCHOOL COLOURING SET', 'WORLD WAR 2 GLIDERS ASSTD DESIGNS'] --> ['TRADITIONAL MODELLING CLAY'] 1.0
# ['MINI PAINT SET VINTAGE ', 'WOODEN SCHOOL COLOURING SET', 'TRADITIONAL MODELLING CLAY'] --> ['WORLD WAR 2 GLIDERS ASSTD DESIGNS'] 1.0
# ['MINI PAINT SET VINTAGE ', 'WOODEN SCHOOL COLOURING SET', 'WORLD WAR 2 GLIDERS ASSTD DESIGNS', 'TRADITIONAL MODELLING CLAY'] --> ['PAINT YOUR OWN CANVAS SET'] 1.0
# ['MINI PAINT SET VINTAGE ', 'WOODEN SCHOOL COLOURING SET', 'WORLD WAR 2 GLIDERS ASSTD DESIGNS', 'PAINT YOUR OWN CANVAS SET'] --> ['TRADITIONAL MODELLING CLAY'] 1.0
# ['MINI PAINT SET VINTAGE ', 'WOODEN SCHOOL COLOURING SET', 'TRADITIONAL MODELLING CLAY', 'PAINT YOUR OWN CANVAS SET'] --> ['WORLD WAR 2 GLIDERS ASSTD DESIGNS'] 1.0
# ['MINI PAINT SET VINTAGE ', 'WORLD WAR 2 GLIDERS ASSTD DESIGNS', 'TRADITIONAL MODELLING CLAY', 'PAINT YOUR OWN CANVAS SET'] --> ['WOODEN SCHOOL COLOURING SET'] 1.0
# ['WOODEN SCHOOL COLOURING SET', 'WORLD WAR 2 GLIDERS ASSTD DESIGNS', 'TRADITIONAL MODELLING CLAY', 'PAINT YOUR OWN CANVAS SET'] --> ['MINI PAINT SET VINTAGE '] 1.0
# ['TRADITIONAL MODELLING CLAY', 'PAINT YOUR OWN CANVAS SET'] --> ['WOODEN SCHOOL COLOURING SET'] 1.0
# ['EDWARDIAN PARASOL PINK', 'POSTAGE'] --> ['EDWARDIAN PARASOL BLACK', 'EDWARDIAN PARASOL NATURAL'] 1.0
# ['EDWARDIAN PARASOL PINK', 'POSTAGE', 'EDWARDIAN PARASOL BLACK'] --> ['EDWARDIAN PARASOL NATURAL'] 1.0
# ['EDWARDIAN PARASOL PINK', 'POSTAGE', 'EDWARDIAN PARASOL NATURAL'] --> ['EDWARDIAN PARASOL BLACK'] 1.0
# ['POSTAGE', 'EDWARDIAN PARASOL BLACK', 'EDWARDIAN PARASOL NATURAL'] --> ['EDWARDIAN PARASOL PINK'] 1.0
# ['PURPLE DRAWERKNOB ACRYLIC EDWARDIAN', 'BLUE SPOT CERAMIC DRAWER KNOB'] --> ['PINK DRAWER KNOB ACRYLIC EDWARDIAN'] 1.4
# ['FELTCRAFT PRINCESS LOLA DOLL', 'FELTCRAFT GIRL NICOLE KIT'] --> ['FELTCRAFT PRINCESS CHARLOTTE DOLL', 'FELTCRAFT GIRL AMELIE KIT'] 1.0
# ['FELTCRAFT DOLL ROSIE', 'FELTCRAFT GIRL NICOLE KIT'] --> ['FELTCRAFT GIRL AMELIE KIT'] 1.0
# ['FELTCRAFT DOLL ROSIE', 'FELTCRAFT GIRL AMELIE KIT'] --> ['FELTCRAFT GIRL NICOLE KIT'] 1.0
# ['FELTCRAFT PRINCESS CHARLOTTE DOLL', 'FELTCRAFT GIRL NICOLE KIT'] --> ['FELTCRAFT PRINCESS LOLA DOLL', 'FELTCRAFT GIRL AMELIE KIT'] 1.0
# ['FELTCRAFT PRINCESS CHARLOTTE DOLL', 'FELTCRAFT GIRL AMELIE KIT'] --> ['FELTCRAFT PRINCESS LOLA DOLL'] 1.0
# ['FELTCRAFT PRINCESS LOLA DOLL', 'FELTCRAFT PRINCESS CHARLOTTE DOLL', 'FELTCRAFT GIRL NICOLE KIT'] --> ['FELTCRAFT GIRL AMELIE KIT'] 1.0
# ['FELTCRAFT PRINCESS LOLA DOLL', 'FELTCRAFT PRINCESS CHARLOTTE DOLL', 'FELTCRAFT GIRL AMELIE KIT'] --> ['FELTCRAFT GIRL NICOLE KIT'] 1.0
# ['FELTCRAFT PRINCESS LOLA DOLL', 'FELTCRAFT GIRL NICOLE KIT', 'FELTCRAFT GIRL AMELIE KIT'] --> ['FELTCRAFT PRINCESS CHARLOTTE DOLL'] 1.0
# ['FELTCRAFT PRINCESS CHARLOTTE DOLL', 'FELTCRAFT GIRL NICOLE KIT', 'FELTCRAFT GIRL AMELIE KIT'] --> ['FELTCRAFT PRINCESS LOLA DOLL'] 1.0
# ['Manual'] --> [] 1.3125
# ['POSTAGE', 'MINI LIGHTS WOODLAND MUSHROOMS'] --> ['RABBIT NIGHT LIGHT'] 1.0
# ['JUMBO BAG TOYS ', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG STRAWBERRY'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG TOYS '] --> ['JUMBO BAG STRAWBERRY'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG STRAWBERRY', 'JUMBO BAG TOYS '] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY', 'JUMBO BAG TOYS '] --> ['JUMBO BAG PINK VINTAGE PAISLEY'] 1.0
# ['JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG TOYS '] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO BAG RED RETROSPOT', 'JUMBO BAG PINK POLKADOT', 'JUMBO BAG TOYS '] --> ['JUMBO  BAG BAROQUE BLACK WHITE'] 1.0
# ['JUMBO BAG PINK POLKADOT', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG TOYS '] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['GLASS APOTHECARY BOTTLE ELIXIR', 'GLASS APOTHECARY BOTTLE PERFUME'] --> ['GLASS APOTHECARY BOTTLE TONIC'] 1.0
# ['RED  HARMONICA IN BOX ', 'BALLOON WATER BOMB PACK OF 35'] --> ['WORLD WAR 2 GLIDERS ASSTD DESIGNS'] 1.0
# ['RED HANGING HEART T-LIGHT HOLDER', 'WASHROOM METAL SIGN'] --> ['WHITE HANGING HEART T-LIGHT HOLDER'] 1.0
# ['STRAWBERRY CHARLOTTE BAG', 'CHARLOTTE BAG ALPHABET  DESIGN'] --> ['CHARLOTTE BAG APPLES DESIGN'] 1.0
# ['LUNCH BAG PAISLEY PARK  ', 'VINTAGE DOILY JUMBO BAG RED '] --> ['JUMBO BAG PAISLEY PARK'] 1.0
# ['PLEASE ONE PERSON METAL SIGN', 'BEWARE OF THE CAT METAL SIGN '] --> ['COOK WITH WINE METAL SIGN '] 1.0
# ['LADIES & GENTLEMEN METAL SIGN', 'BEWARE OF THE CAT METAL SIGN '] --> ['COOK WITH WINE METAL SIGN '] 1.0
# ['FELTCRAFT PRINCESS LOLA DOLL', 'PINK BLUE FELT CRAFT TRINKET BOX'] --> ['FELTCRAFT GIRL AMELIE KIT'] 1.0
# ['FELTCRAFT DOLL ROSIE', 'FELTCRAFT PRINCESS LOLA DOLL', 'FELTCRAFT DOLL MOLLY'] --> ['FELTCRAFT PRINCESS CHARLOTTE DOLL'] 1.4
# ['FELTCRAFT PRINCESS LOLA DOLL', 'FELTCRAFT DOLL MOLLY', 'FELTCRAFT PRINCESS CHARLOTTE DOLL'] --> ['FELTCRAFT DOLL ROSIE'] 1.0
# ['FELTCRAFT DOLL ROSIE', 'FELTCRAFT PRINCESS LOLA DOLL'] --> ['FELTCRAFT PRINCESS CHARLOTTE DOLL'] 1.125
# ['RECYCLED ACAPULCO MAT PINK', 'RECYCLED ACAPULCO MAT TURQUOISE', 'RECYCLED ACAPULCO MAT BLUE'] --> ['RECYCLED ACAPULCO MAT GREEN'] 1.0
# ['RECYCLED ACAPULCO MAT RED', 'RECYCLED ACAPULCO MAT PINK', 'RECYCLED ACAPULCO MAT BLUE'] --> ['RECYCLED ACAPULCO MAT GREEN'] 1.0
# ['RECYCLED ACAPULCO MAT RED', 'RECYCLED ACAPULCO MAT PINK', 'RECYCLED ACAPULCO MAT TURQUOISE', 'RECYCLED ACAPULCO MAT BLUE'] --> ['RECYCLED ACAPULCO MAT GREEN'] 1.0
# ['RECYCLED ACAPULCO MAT PINK', 'RECYCLED ACAPULCO MAT GREEN', 'RECYCLED ACAPULCO MAT TURQUOISE', 'RECYCLED ACAPULCO MAT BLUE'] --> ['RECYCLED ACAPULCO MAT RED'] 1.1428571428571428
# ['RECYCLED ACAPULCO MAT RED', 'RECYCLED ACAPULCO MAT PINK', 'RECYCLED ACAPULCO MAT TURQUOISE'] --> ['RECYCLED ACAPULCO MAT GREEN'] 1.0
# ['SET OF 20 KIDS COOKIE CUTTERS', 'ROUND SNACK BOXES SET OF 4 FRUITS '] --> ['SET OF 3 BUTTERFLY COOKIE CUTTERS'] 1.0
# ['SET OF 3 BUTTERFLY COOKIE CUTTERS', 'ROUND SNACK BOXES SET OF 4 FRUITS '] --> ['SET OF 20 KIDS COOKIE CUTTERS'] 1.0
# ['BLACK HEART CARD HOLDER', 'MEMO BOARD RETROSPOT  DESIGN'] --> ['CREAM HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['CREAM HEART CARD HOLDER', 'MEMO BOARD RETROSPOT  DESIGN'] --> ['WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['CREAM HEART CARD HOLDER', 'BLACK HEART CARD HOLDER', 'MEMO BOARD RETROSPOT  DESIGN'] --> ['WOOD BLACK BOARD ANT WHITE FINISH'] 1.0
# ['CREAM HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH', 'MEMO BOARD RETROSPOT  DESIGN'] --> ['BLACK HEART CARD HOLDER'] 1.0
# ['BLACK HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH', 'MEMO BOARD RETROSPOT  DESIGN'] --> ['CREAM HEART CARD HOLDER'] 1.0
# ['BLACK HEART CARD HOLDER', 'WOOD BLACK BOARD ANT WHITE FINISH'] --> ['CREAM HEART CARD HOLDER'] 1.0
# ['RED FLORAL FELTCRAFT SHOULDER BAG', 'FELTCRAFT BUTTERFLY HEARTS'] --> ['FELTCRAFT CUSHION OWL'] 1.0
# ['FELTCRAFT CUSHION RABBIT', 'RED FLORAL FELTCRAFT SHOULDER BAG'] --> ['FELTCRAFT CUSHION BUTTERFLY'] 1.0
# ['FELTCRAFT CUSHION RABBIT', 'FELTCRAFT CUSHION OWL', 'RED FLORAL FELTCRAFT SHOULDER BAG'] --> ['FELTCRAFT CUSHION BUTTERFLY'] 1.0
# ['HAND WARMER RED RETROSPOT', 'HAND WARMER SCOTTY DOG DESIGN', 'HAND WARMER BIRD DESIGN'] --> ['HAND WARMER OWL DESIGN'] 1.0
# ['FELTCRAFT CUSHION BUTTERFLY', 'FELTCRAFT DOLL MOLLY'] --> ['FELTCRAFT CUSHION RABBIT'] 1.0
# ['FELTCRAFT DOLL MOLLY', 'FELTCRAFT BUTTERFLY HEARTS'] --> ['PINK BLUE FELT CRAFT TRINKET BOX'] 1.0
# ['VINTAGE SNAP CARDS', 'TRAVEL CARD WALLET KEEP CALM'] --> ['BAG 250g SWIRLY MARBLES'] 1.0
# ['ALARM CLOCK BAKELIKE GREEN', 'VINTAGE SNAP CARDS'] --> ['BAG 250g SWIRLY MARBLES'] 1.0
# ['ALARM CLOCK BAKELIKE CHOCOLATE', 'VINTAGE SNAP CARDS'] --> ['BAG 250g SWIRLY MARBLES'] 1.0
# [' SET 2 TEA TOWELS I LOVE LONDON ', 'QUEENS GUARD COFFEE MUG'] --> ['LONDON BUS COFFEE MUG'] 1.0
# ['REGENCY CAKESTAND 3 TIER', 'REGENCY SUGAR BOWL GREEN'] --> ['REGENCY MILK JUG PINK '] 1.0
# ['PINK REGENCY TEACUP AND SAUCER', 'REGENCY SUGAR BOWL GREEN', 'REGENCY TEA PLATE GREEN '] --> ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER'] 1.0
# ['GREEN REGENCY TEACUP AND SAUCER', 'REGENCY SUGAR BOWL GREEN', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEA PLATE ROSES '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY SUGAR BOWL GREEN', 'REGENCY TEA PLATE GREEN '] --> ['PINK REGENCY TEACUP AND SAUCER'] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY SUGAR BOWL GREEN', 'REGENCY TEA PLATE GREEN '] --> ['GREEN REGENCY TEACUP AND SAUCER'] 1.0
# ['GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY SUGAR BOWL GREEN', 'REGENCY TEA PLATE GREEN '] --> ['ROSES REGENCY TEACUP AND SAUCER '] 1.0
# ['PINK REGENCY TEACUP AND SAUCER', 'REGENCY MILK JUG PINK ', 'REGENCY SUGAR BOWL GREEN'] --> ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER'] 1.0
# ['GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY MILK JUG PINK '] --> ['ROSES REGENCY TEACUP AND SAUCER '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY MILK JUG PINK '] --> ['REGENCY SUGAR BOWL GREEN'] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY MILK JUG PINK ', 'REGENCY SUGAR BOWL GREEN'] --> ['GREEN REGENCY TEACUP AND SAUCER'] 1.0
# ['GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY MILK JUG PINK ', 'REGENCY SUGAR BOWL GREEN'] --> ['ROSES REGENCY TEACUP AND SAUCER '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY SUGAR BOWL GREEN'] --> ['GREEN REGENCY TEACUP AND SAUCER'] 1.0
# ['GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY SUGAR BOWL GREEN'] --> ['ROSES REGENCY TEACUP AND SAUCER '] 1.0
# ['REGENCY SUGAR BOWL GREEN', 'REGENCY TEA PLATE PINK'] --> ['REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] 1.0
# ['REGENCY SUGAR BOWL GREEN', 'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE ROSES '] --> ['REGENCY TEA PLATE GREEN '] 1.0
# ['REGENCY SUGAR BOWL GREEN', 'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEA PLATE ROSES '] 1.0
# ['GREEN REGENCY TEACUP AND SAUCER', 'REGENCY SUGAR BOWL GREEN', 'REGENCY TEA PLATE ROSES '] --> ['REGENCY TEA PLATE GREEN '] 1.0
# ['GREEN REGENCY TEACUP AND SAUCER', 'REGENCY SUGAR BOWL GREEN', 'REGENCY TEAPOT ROSES '] --> ['REGENCY MILK JUG PINK '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY MILK JUG PINK ', 'REGENCY TEAPOT ROSES '] --> ['REGENCY SUGAR BOWL GREEN'] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY SUGAR BOWL GREEN', 'REGENCY TEAPOT ROSES '] --> ['REGENCY MILK JUG PINK '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY MILK JUG PINK '] --> ['REGENCY SUGAR BOWL GREEN'] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY MILK JUG PINK ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE ROSES '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY SUGAR BOWL GREEN', 'REGENCY TEA PLATE ROSES '] --> ['REGENCY MILK JUG PINK ', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE GREEN '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY SUGAR BOWL GREEN', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEA PLATE ROSES '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY MILK JUG PINK ', 'REGENCY SUGAR BOWL GREEN', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE ROSES '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY MILK JUG PINK ', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEA PLATE ROSES '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY SUGAR BOWL GREEN', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY MILK JUG PINK ', 'REGENCY TEA PLATE ROSES '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY MILK JUG PINK ', 'REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEAPOT ROSES '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY MILK JUG PINK ', 'REGENCY SUGAR BOWL GREEN', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEA PLATE ROSES '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY MILK JUG PINK ', 'REGENCY SUGAR BOWL GREEN', 'REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEAPOT ROSES '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY MILK JUG PINK ', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY SUGAR BOWL GREEN'] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY SUGAR BOWL GREEN', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY MILK JUG PINK '] 1.0
# ['REGENCY SUGAR BOWL GREEN', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE ROSES '] --> ['REGENCY MILK JUG PINK '] 1.0
# ['REGENCY SUGAR BOWL GREEN', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY MILK JUG PINK ', 'REGENCY TEA PLATE ROSES '] 1.0
# ['REGENCY MILK JUG PINK ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE ROSES '] 1.0
# ['REGENCY MILK JUG PINK ', 'REGENCY SUGAR BOWL GREEN', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE ROSES '] 1.0
# ['REGENCY MILK JUG PINK ', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEA PLATE ROSES '] 1.0
# ['REGENCY MILK JUG PINK ', 'REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEAPOT ROSES '] 1.0
# ['REGENCY MILK JUG PINK ', 'REGENCY SUGAR BOWL GREEN', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE ROSES '] --> ['REGENCY TEA PLATE GREEN '] 1.0
# ['REGENCY MILK JUG PINK ', 'REGENCY SUGAR BOWL GREEN', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEA PLATE ROSES '] 1.0
# ['REGENCY MILK JUG PINK ', 'REGENCY SUGAR BOWL GREEN', 'REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEAPOT ROSES '] 1.0
# ['REGENCY MILK JUG PINK ', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY SUGAR BOWL GREEN'] 1.0
# ['REGENCY SUGAR BOWL GREEN', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY MILK JUG PINK '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY MILK JUG PINK ', 'REGENCY TEAPOT ROSES '] --> ['REGENCY SUGAR BOWL GREEN'] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY SUGAR BOWL GREEN', 'REGENCY TEAPOT ROSES '] --> ['REGENCY MILK JUG PINK '] 1.0
# ['REGENCY SUGAR BOWL GREEN', 'REGENCY TEAPOT ROSES '] --> ['REGENCY MILK JUG PINK '] 1.0
# ['POSTAGE', 'SET OF 6 TEA TIME BAKING CASES'] --> ['SET OF 12 FAIRY CAKE BAKING CASES', 'SET OF 12 MINI LOAF BAKING CASES'] 1.0
# ['POSTAGE', 'SET OF 12 MINI LOAF BAKING CASES'] --> ['SET OF 12 FAIRY CAKE BAKING CASES'] 1.0
# ['POSTAGE', 'SET OF 6 TEA TIME BAKING CASES', 'SET OF 12 FAIRY CAKE BAKING CASES'] --> ['SET OF 12 MINI LOAF BAKING CASES'] 1.0
# ['POSTAGE', 'SET OF 6 TEA TIME BAKING CASES', 'SET OF 12 MINI LOAF BAKING CASES'] --> ['SET OF 12 FAIRY CAKE BAKING CASES'] 1.0
# ['POSTAGE', 'SET OF 12 FAIRY CAKE BAKING CASES', 'SET OF 12 MINI LOAF BAKING CASES'] --> ['SET OF 6 TEA TIME BAKING CASES'] 1.0
# ['POSTAGE', 'SET OF 6 SNACK LOAF BAKING CASES', 'SET OF 12 FAIRY CAKE BAKING CASES'] --> ['SET OF 12 MINI LOAF BAKING CASES'] 1.0
# ['POSTAGE', 'SET OF 6 SNACK LOAF BAKING CASES', 'SET OF 12 MINI LOAF BAKING CASES'] --> ['SET OF 12 FAIRY CAKE BAKING CASES'] 1.0
# ['PACK OF 60 DINOSAUR CAKE CASES', 'PACK OF 72 SKULL CAKE CASES', '60 TEATIME FAIRY CAKE CASES'] --> ['PACK OF 60 PINK PAISLEY CAKE CASES'] 1.0
# ['RED RETROSPOT UMBRELLA', 'EDWARDIAN PARASOL BLACK'] --> ['EDWARDIAN PARASOL RED', 'EDWARDIAN PARASOL NATURAL'] 1.0
# ['RED RETROSPOT UMBRELLA', 'EDWARDIAN PARASOL BLACK', 'EDWARDIAN PARASOL RED'] --> ['EDWARDIAN PARASOL NATURAL'] 1.0
# ['RED RETROSPOT UMBRELLA', 'EDWARDIAN PARASOL BLACK', 'EDWARDIAN PARASOL NATURAL'] --> ['EDWARDIAN PARASOL RED'] 1.0
# ['WORLD WAR 2 GLIDERS ASSTD DESIGNS', 'TRADITIONAL MODELLING CLAY'] --> ['WOODEN SCHOOL COLOURING SET'] 1.0
# ['DOORMAT RED RETROSPOT', 'DOORMAT WELCOME PUPPIES'] --> ['DOORMAT HEARTS'] 1.0
# ['FELTCRAFT 6 FLOWER FRIENDS', 'FELTCRAFT CUSHION RABBIT'] --> ['FELTCRAFT CUSHION BUTTERFLY'] 1.0
# ['JUMBO BAG APPLES', 'JUMBO BAG VINTAGE CHRISTMAS '] --> ["JUMBO BAG 50'S CHRISTMAS "] 1.0
# ['JUMBO BAG PEARS', 'JUMBO BAG VINTAGE CHRISTMAS '] --> ["JUMBO BAG 50'S CHRISTMAS "] 1.0
# ['HOT BATHS METAL SIGN', 'NO SINGING METAL SIGN'] --> ['COOK WITH WINE METAL SIGN '] 1.0
# ['PLEASE ONE PERSON METAL SIGN', 'NO SINGING METAL SIGN', 'GIN + TONIC DIET METAL SIGN'] --> ['COOK WITH WINE METAL SIGN '] 1.0
# ['PLEASE ONE PERSON METAL SIGN', 'HAND OVER THE CHOCOLATE   SIGN ', 'NO SINGING METAL SIGN'] --> ['COOK WITH WINE METAL SIGN '] 1.0
# ['HAND OVER THE CHOCOLATE   SIGN ', 'NO SINGING METAL SIGN', 'GIN + TONIC DIET METAL SIGN'] --> ['COOK WITH WINE METAL SIGN '] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG RED RETROSPOT', 'JUMBO BAG PINK POLKADOT'] 1.0
# ['JUMBO BAG SCANDINAVIAN PAISLEY', 'JUMBO BAG PINK POLKADOT', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG PINK POLKADOT'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'JUMBO BAG PINK POLKADOT', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO BAG RED RETROSPOT', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'JUMBO BAG PINK POLKADOT', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG PINK VINTAGE PAISLEY'] 1.0
# ['JUMBO BAG STRAWBERRY', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG STRAWBERRY', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG STRAWBERRY', 'JUMBO BAG PINK POLKADOT', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG RED RETROSPOT', 'JUMBO  BAG BAROQUE BLACK WHITE'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG PINK POLKADOT', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY', 'JUMBO BAG PINK POLKADOT'] 1.0
# ['JUMBO BAG PINK POLKADOT', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY'] 1.0
# ['JUMBO BAG RED RETROSPOT', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG STRAWBERRY', 'JUMBO BAG PINK POLKADOT'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG STRAWBERRY', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG RED RETROSPOT', 'JUMBO BAG PINK POLKADOT'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG PINK POLKADOT', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY'] 1.0
# ['JUMBO BAG STRAWBERRY', 'JUMBO BAG PINK POLKADOT', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG STRAWBERRY', 'JUMBO BAG PINK POLKADOT'] 1.0
# ['JUMBO BAG RED RETROSPOT', 'JUMBO BAG PINK POLKADOT', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG STRAWBERRY'] 1.0
# ['JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG PINK POLKADOT'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY', 'JUMBO BAG PINK POLKADOT', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO  BAG BAROQUE BLACK WHITE'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG PINK POLKADOT'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG PINK POLKADOT', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG STRAWBERRY'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG STRAWBERRY', 'JUMBO BAG PINK POLKADOT', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY', 'JUMBO BAG PINK POLKADOT', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG PINK VINTAGE PAISLEY'] 1.0
# ['JUMBO BAG STRAWBERRY', 'JUMBO BAG OWLS', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG PINK POLKADOT'] 1.0
# ['JUMBO BAG PINK POLKADOT', 'JUMBO BAG OWLS', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG STRAWBERRY'] 1.0
# ['JUMBO BAG RED RETROSPOT', 'JUMBO BAG OWLS', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG STRAWBERRY', 'JUMBO BAG PINK POLKADOT'] 1.0
# ['JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY', 'JUMBO BAG OWLS', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG PINK POLKADOT'] 1.0
# ['JUMBO BAG RED RETROSPOT', 'JUMBO BAG PINK POLKADOT', 'JUMBO BAG OWLS', 'JUMBO BAG SPACEBOY DESIGN'] --> ['JUMBO BAG STRAWBERRY'] 1.0
# ['LUNCH BAG VINTAGE LEAF DESIGN', 'JUMBO BAG DOILEY PATTERNS'] --> ['LUNCH BAG DOILEY PATTERN '] 1.0
# ['LUNCH BAG VINTAGE LEAF DESIGN', 'JUMBO BAG DOILEY PATTERNS', 'JUMBO BAG VINTAGE LEAF'] --> ['LUNCH BAG DOILEY PATTERN '] 1.0
# ['PINK REGENCY TEACUP AND SAUCER', 'REGENCY MILK JUG PINK '] --> ['ROSES REGENCY TEACUP AND SAUCER '] 1.0
# ['REGENCY MILK JUG PINK ', 'REGENCY TEA PLATE PINK'] --> ['REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE ROSES '] 1.0
# ['REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE PINK'] --> ['REGENCY TEA PLATE ROSES '] 1.0
# ['REGENCY MILK JUG PINK ', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE PINK'] --> ['REGENCY TEA PLATE ROSES '] 1.0
# ['REGENCY MILK JUG PINK ', 'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE ROSES '] --> ['REGENCY TEAPOT ROSES '] 1.0
# ['REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE ROSES '] --> ['REGENCY MILK JUG PINK '] 1.0
# ['REGENCY CAKESTAND 3 TIER', 'REGENCY TEA PLATE PINK'] --> ['REGENCY TEA PLATE ROSES '] 1.0
# ['REGENCY CAKESTAND 3 TIER', 'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEA PLATE ROSES '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY TEA PLATE PINK'] --> ['GREEN REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE PINK'] --> ['REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE ROSES '] --> ['GREEN REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE GREEN '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE GREEN '] --> ['GREEN REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE ROSES '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE PINK'] --> ['GREEN REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE ROSES '] --> ['REGENCY TEA PLATE GREEN '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEA PLATE ROSES '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['GREEN REGENCY TEACUP AND SAUCER'] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE PINK'] --> ['REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE ROSES '] --> ['GREEN REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE GREEN '] 1.0
# ['GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE ROSES '] --> ['REGENCY TEA PLATE GREEN '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE GREEN '] --> ['GREEN REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE ROSES '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE ROSES '] --> ['REGENCY TEA PLATE GREEN '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEA PLATE ROSES '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['GREEN REGENCY TEACUP AND SAUCER'] 1.0
# ['GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['ROSES REGENCY TEACUP AND SAUCER '] 1.0
# ['GREEN REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE ROSES '] --> ['REGENCY TEA PLATE GREEN '] 1.0
# ['PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE ROSES '] --> ['REGENCY TEA PLATE GREEN '] 1.0
# ['JUMBO BAG STRAWBERRY', 'STRAWBERRY CHARLOTTE BAG'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO STORAGE BAG SUKI', 'JUMBO BAG PAISLEY PARK'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['RED WOOLLY HOTTIE WHITE HEART.', 'HOT WATER BOTTLE I AM SO POORLY'] --> ['CHOCOLATE HOT WATER BOTTLE'] 1.0
# ['FINE WICKER HEART ', 'HEART OF WICKER LARGE'] --> ['HEART OF WICKER SMALL'] 1.0
# ['PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER'] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE ROSES '] --> ['GREEN REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE GREEN '] 1.2
# ['ROSES REGENCY TEACUP AND SAUCER ', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['GREEN REGENCY TEACUP AND SAUCER'] 1.0
# ['PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['GREEN REGENCY TEACUP AND SAUCER'] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE ROSES '] --> ['REGENCY TEA PLATE GREEN '] 1.2
# ['GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEAPOT ROSES '] --> ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY TEA PLATE GREEN '] 1.0
# ['GREEN REGENCY TEACUP AND SAUCER', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEA PLATE ROSES '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEAPOT ROSES '] --> ['REGENCY TEA PLATE GREEN '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEA PLATE ROSES '] 1.0
# ['GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['ROSES REGENCY TEACUP AND SAUCER '] 1.0
# ['GREEN REGENCY TEACUP AND SAUCER', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['ROSES REGENCY TEACUP AND SAUCER '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE ROSES '] --> ['REGENCY TEA PLATE GREEN '] 1.2
# ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEA PLATE ROSES '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['PINK REGENCY TEACUP AND SAUCER'] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['GREEN REGENCY TEACUP AND SAUCER'] 1.0
# ['GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['ROSES REGENCY TEACUP AND SAUCER '] 1.0
# ['REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEA PLATE ROSES '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE ROSES '] --> ['REGENCY TEA PLATE GREEN '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY TEAPOT ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEA PLATE ROSES '] 1.0
# ['ALARM CLOCK BAKELIKE GREEN', 'BLUE DINER WALL CLOCK', 'RED DINER WALL CLOCK'] --> ['ALARM CLOCK BAKELIKE RED '] 1.0
# ['SINGLE HEART ZINC T-LIGHT HOLDER', 'HANGING HEART JAR T-LIGHT HOLDER'] --> ['HANGING HEART ZINC T-LIGHT HOLDER'] 1.0
# ['JUMBO BAG OWLS', 'LUNCH BAG APPLE DESIGN'] --> ['JUMBO STORAGE BAG SUKI'] 1.0
# ['JUMBO BAG STRAWBERRY', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG OWLS'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO BAG ALPHABET', 'JUMBO BAG PEARS'] --> ['JUMBO BAG APPLES'] 1.0
# ['JUMBO BAG PINK POLKADOT', 'JUMBO BAG PEARS'] --> ['JUMBO BAG APPLES'] 1.0
# ['JUMBO BAG APPLES', 'JUMBO BAG VINTAGE LEAF', "JUMBO BAG 50'S CHRISTMAS "] --> ['JUMBO BAG PEARS'] 1.0
# ['JUMBO BAG VINTAGE LEAF', 'JUMBO BAG PEARS', "JUMBO BAG 50'S CHRISTMAS "] --> ['JUMBO BAG APPLES'] 1.0
# ['SCOTTIE DOG HOT WATER BOTTLE', 'HAND WARMER BIRD DESIGN'] --> ['HAND WARMER SCOTTY DOG DESIGN'] 1.0
# ['SCOTTIE DOG HOT WATER BOTTLE', 'HAND WARMER BIRD DESIGN', 'HOT WATER BOTTLE TEA AND SYMPATHY'] --> ['HAND WARMER OWL DESIGN', 'HAND WARMER SCOTTY DOG DESIGN'] 1.0
# ['HAND WARMER SCOTTY DOG DESIGN', 'HAND WARMER BIRD DESIGN', 'HOT WATER BOTTLE TEA AND SYMPATHY'] --> ['HAND WARMER OWL DESIGN'] 1.0
# ['SCOTTIE DOG HOT WATER BOTTLE', 'HAND WARMER OWL DESIGN', 'HAND WARMER BIRD DESIGN'] --> ['HAND WARMER SCOTTY DOG DESIGN', 'HOT WATER BOTTLE TEA AND SYMPATHY'] 1.0
# ['SCOTTIE DOG HOT WATER BOTTLE', 'HAND WARMER OWL DESIGN', 'HOT WATER BOTTLE TEA AND SYMPATHY'] --> ['HAND WARMER SCOTTY DOG DESIGN'] 1.0
# ['SCOTTIE DOG HOT WATER BOTTLE', 'HAND WARMER OWL DESIGN', 'HAND WARMER SCOTTY DOG DESIGN'] --> ['HOT WATER BOTTLE TEA AND SYMPATHY'] 1.0
# ['SCOTTIE DOG HOT WATER BOTTLE', 'HAND WARMER OWL DESIGN', 'HAND WARMER SCOTTY DOG DESIGN', 'HAND WARMER BIRD DESIGN'] --> ['HOT WATER BOTTLE TEA AND SYMPATHY'] 1.0
# ['SCOTTIE DOG HOT WATER BOTTLE', 'HAND WARMER OWL DESIGN', 'HAND WARMER SCOTTY DOG DESIGN', 'HOT WATER BOTTLE TEA AND SYMPATHY'] --> ['HAND WARMER BIRD DESIGN'] 1.0
# ['SCOTTIE DOG HOT WATER BOTTLE', 'HAND WARMER OWL DESIGN', 'HAND WARMER BIRD DESIGN', 'HOT WATER BOTTLE TEA AND SYMPATHY'] --> ['HAND WARMER SCOTTY DOG DESIGN'] 1.0
# ['SCOTTIE DOG HOT WATER BOTTLE', 'HAND WARMER SCOTTY DOG DESIGN', 'HAND WARMER BIRD DESIGN', 'HOT WATER BOTTLE TEA AND SYMPATHY'] --> ['HAND WARMER OWL DESIGN'] 1.0
# ['HAND WARMER OWL DESIGN', 'HAND WARMER SCOTTY DOG DESIGN', 'HAND WARMER BIRD DESIGN', 'HOT WATER BOTTLE TEA AND SYMPATHY'] --> ['SCOTTIE DOG HOT WATER BOTTLE'] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY TEA PLATE ROSES '] --> ['REGENCY TEA PLATE GREEN '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEA PLATE ROSES '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE ROSES '] --> ['PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE GREEN '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEA PLATE ROSES '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE GREEN '] --> ['GREEN REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE ROSES '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE ROSES '] --> ['GREEN REGENCY TEACUP AND SAUCER'] 1.0
# ['GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE ROSES '] --> ['ROSES REGENCY TEACUP AND SAUCER '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE ROSES '] --> ['REGENCY TEA PLATE GREEN '] 1.1111111111111112
# ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE GREEN '] --> ['REGENCY TEA PLATE ROSES '] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['GREEN REGENCY TEACUP AND SAUCER'] 1.0
# ['GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE ROSES ', 'REGENCY TEA PLATE GREEN '] --> ['ROSES REGENCY TEACUP AND SAUCER '] 1.0
# ['PINK REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE ROSES '] --> ['REGENCY TEA PLATE GREEN '] 1.0
# ['GREEN REGENCY TEACUP AND SAUCER', 'REGENCY TEA PLATE ROSES '] --> ['REGENCY TEA PLATE GREEN '] 1.0
# ['RETROSPOT HEART HOT WATER BOTTLE', 'CHOCOLATE HOT WATER BOTTLE', 'HOT WATER BOTTLE TEA AND SYMPATHY'] --> ['HOT WATER BOTTLE I AM SO POORLY'] 1.0
# ['ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE ORANGE', 'ALARM CLOCK BAKELIKE CHOCOLATE'] --> ['ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE IVORY'] 1.0
# ['ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE ORANGE', 'ALARM CLOCK BAKELIKE CHOCOLATE'] --> ['ALARM CLOCK BAKELIKE IVORY'] 1.4
# ['ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE ORANGE', 'ALARM CLOCK BAKELIKE CHOCOLATE', 'ALARM CLOCK BAKELIKE IVORY'] --> ['ALARM CLOCK BAKELIKE PINK'] 1.0
# ['ALARM CLOCK BAKELIKE ORANGE', 'ALARM CLOCK BAKELIKE CHOCOLATE', 'ALARM CLOCK BAKELIKE IVORY', 'ALARM CLOCK BAKELIKE RED '] --> ['ALARM CLOCK BAKELIKE PINK'] 1.0
# ['HEART OF WICKER LARGE', 'SMALL WHITE HEART OF WICKER'] --> ['LARGE WHITE HEART OF WICKER'] 1.0
# ['PLEASE ONE PERSON METAL SIGN', 'HAND OVER THE CHOCOLATE   SIGN ', 'GIN + TONIC DIET METAL SIGN'] --> ['COOK WITH WINE METAL SIGN '] 1.0
# ['DOORMAT UNION FLAG', 'EDWARDIAN PARASOL BLACK'] --> ['EDWARDIAN PARASOL NATURAL'] 1.0
# ['ALARM CLOCK BAKELIKE GREEN', 'RED DINER WALL CLOCK'] --> ['ALARM CLOCK BAKELIKE RED '] 1.0
# ['DOORMAT FANCY FONT HOME SWEET HOME', 'HOME BUILDING BLOCK WORD'] --> ['LOVE BUILDING BLOCK WORD'] 1.0
# ['DOORMAT FANCY FONT HOME SWEET HOME', 'LOVE BUILDING BLOCK WORD'] --> ['HOME BUILDING BLOCK WORD'] 1.0
# ['DOORMAT FANCY FONT HOME SWEET HOME', 'DOORMAT NEW ENGLAND', 'DOORMAT HEARTS'] --> ['DOORMAT RED RETROSPOT'] 1.0
# ['DOORMAT FANCY FONT HOME SWEET HOME', 'DOORMAT HEARTS', 'DOORMAT RED RETROSPOT'] --> ['DOORMAT NEW ENGLAND'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG VINTAGE LEAF'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG PINK POLKADOT', 'JUMBO  BAG BAROQUE BLACK WHITE'] --> ['JUMBO BAG STRAWBERRY'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG STRAWBERRY', 'JUMBO BAG PINK POLKADOT', 'JUMBO  BAG BAROQUE BLACK WHITE'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'JUMBO  BAG BAROQUE BLACK WHITE'] --> ['JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'JUMBO BAG PINK POLKADOT', 'JUMBO  BAG BAROQUE BLACK WHITE'] --> ['JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY'] 1.0
# ['JUMBO BAG STRAWBERRY', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'JUMBO BAG PINK POLKADOT', 'JUMBO  BAG BAROQUE BLACK WHITE'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'JUMBO  BAG BAROQUE BLACK WHITE'] --> ['JUMBO BAG STRAWBERRY'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG STRAWBERRY', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'JUMBO  BAG BAROQUE BLACK WHITE'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'JUMBO BAG PINK POLKADOT', 'JUMBO  BAG BAROQUE BLACK WHITE'] --> ['JUMBO BAG STRAWBERRY'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG STRAWBERRY', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'JUMBO BAG PINK POLKADOT', 'JUMBO  BAG BAROQUE BLACK WHITE'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'JUMBO BAG PINK POLKADOT', 'JUMBO  BAG BAROQUE BLACK WHITE'] --> ['JUMBO BAG PINK VINTAGE PAISLEY'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT', 'JUMBO  BAG BAROQUE BLACK WHITE'] --> ['JUMBO BAG STRAWBERRY'] 1.0
# ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG STRAWBERRY', 'JUMBO  BAG BAROQUE BLACK WHITE'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO BAG STRAWBERRY', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'JUMBO BAG PINK POLKADOT'] --> ['JUMBO BAG PINK VINTAGE PAISLEY'] 1.0
# ['JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'JUMBO BAG PINK POLKADOT'] --> ['JUMBO BAG PINK VINTAGE PAISLEY'] 1.0
# ['JUMBO BAG SCANDINAVIAN PAISLEY', 'JUMBO BAG PINK POLKADOT', 'JUMBO  BAG BAROQUE BLACK WHITE'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO BAG SCANDINAVIAN PAISLEY', 'JUMBO  BAG BAROQUE BLACK WHITE'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO BAG STRAWBERRY', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'JUMBO  BAG BAROQUE BLACK WHITE'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO BAG RED RETROSPOT', 'JUMBO BAG ALPHABET', 'JUMBO BAG VINTAGE LEAF'] --> ['JUMBO SHOPPER VINTAGE RED PAISLEY'] 1.0
# ['JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO BAG ALPHABET', 'JUMBO BAG VINTAGE LEAF'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG VINTAGE LEAF'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO SHOPPER VINTAGE RED PAISLEY', 'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG DOILEY PATTERNS'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['LUNCH BAG SUKI  DESIGN ', 'LUNCH BAG  BLACK SKULL.', 'LUNCH BAG RED RETROSPOT'] --> ['LUNCH BAG PINK POLKADOT'] 1.0
# ['LUNCH BAG PINK POLKADOT', 'LUNCH BAG  BLACK SKULL.', 'LUNCH BAG RED RETROSPOT', 'LUNCH BAG CARS BLUE'] --> ['LUNCH BAG SUKI  DESIGN '] 1.0
# ['JUMBO BAG STRAWBERRY', 'JUMBO STORAGE BAG SUKI', 'JUMBO BAG PINK POLKADOT'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['JUMBO BAG STRAWBERRY', 'JUMBO BAG PINK POLKADOT', 'JUMBO  BAG BAROQUE BLACK WHITE'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['SMALL POPCORN HOLDER', 'JUMBO BAG ALPHABET'] --> ['JUMBO BAG DOILEY PATTERNS'] 1.0
# ['ASSORTED COLOUR BIRD ORNAMENT', 'JUMBO BAG ALPHABET'] --> ['JUMBO BAG DOILEY PATTERNS'] 1.0
# ['JUMBO BAG STRAWBERRY', 'JUMBO BAG PINK POLKADOT', 'JUMBO BAG ALPHABET'] --> ['JUMBO BAG RED RETROSPOT'] 1.0
# ['ASSORTED COLOUR BIRD ORNAMENT', 'PINK REGENCY TEACUP AND SAUCER'] --> ['GREEN REGENCY TEACUP AND SAUCER'] 1.0
# ['ALARM CLOCK BAKELIKE RED ', 'ROSES REGENCY TEACUP AND SAUCER '] --> ['GREEN REGENCY TEACUP AND SAUCER'] 1.2
# ['ALARM CLOCK BAKELIKE RED ', 'PINK REGENCY TEACUP AND SAUCER'] --> ['ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER'] 1.0
# ['ALARM CLOCK BAKELIKE RED ', 'ROSES REGENCY TEACUP AND SAUCER ', 'PINK REGENCY TEACUP AND SAUCER'] --> ['GREEN REGENCY TEACUP AND SAUCER'] 1.0
# ['ALARM CLOCK BAKELIKE RED ', 'GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER'] --> ['ROSES REGENCY TEACUP AND SAUCER '] 1.0
# ['GREEN REGENCY TEACUP AND SAUCER', 'VICTORIAN GLASS HANGING T-LIGHT'] --> ['PINK REGENCY TEACUP AND SAUCER'] 1.0
# ['VICTORIAN GLASS HANGING T-LIGHT', 'PINK REGENCY TEACUP AND SAUCER'] --> ['GREEN REGENCY TEACUP AND SAUCER'] 1.0
# ['ANTIQUE SILVER TEA GLASS ETCHED', 'GREEN REGENCY TEACUP AND SAUCER'] --> ['PINK REGENCY TEACUP AND SAUCER'] 1.2
# ['ANTIQUE SILVER TEA GLASS ETCHED', 'PINK REGENCY TEACUP AND SAUCER'] --> ['GREEN REGENCY TEACUP AND SAUCER'] 1.0
# ['REGENCY CAKESTAND 3 TIER', 'GREEN REGENCY TEACUP AND SAUCER', 'PARTY BUNTING'] --> ['PINK REGENCY TEACUP AND SAUCER'] 1.0
# ['REGENCY CAKESTAND 3 TIER', 'PARTY BUNTING', 'PINK REGENCY TEACUP AND SAUCER'] --> ['GREEN REGENCY TEACUP AND SAUCER'] 1.0
# ['ROSES REGENCY TEACUP AND SAUCER ', 'PARTY BUNTING', 'PINK REGENCY TEACUP AND SAUCER'] --> ['GREEN REGENCY TEACUP AND SAUCER'] 1.0
# ['RED HANGING HEART T-LIGHT HOLDER', 'HEART OF WICKER LARGE', 'HEART OF WICKER SMALL'] --> ['WHITE HANGING HEART T-LIGHT HOLDER'] 1.0
# ['ALARM CLOCK BAKELIKE GREEN', 'ROSES REGENCY TEACUP AND SAUCER '] --> ['ALARM CLOCK BAKELIKE RED '] 1.0
# ['ALARM CLOCK BAKELIKE RED ', 'GREEN REGENCY TEACUP AND SAUCER'] --> ['ROSES REGENCY TEACUP AND SAUCER '] 1.0
# ['ASSORTED COLOUR BIRD ORNAMENT', 'ROSES REGENCY TEACUP AND SAUCER '] --> ['GREEN REGENCY TEACUP AND SAUCER'] 1.0

# %% [markdown]
# This is the end of Lab 3
#
# **Ceni Babaoglu, PhD**
#
# The Chang School of Continuing Education
#
# Ryerson University
